# %%
method 1
10 0.000000 inf
20 0.000000 inf
50 0.000000 inf
100 0.000000 inf
200 0.010000 16.000000
500 0.090000 11.111111
1000 0.370000 10.810811
2000 1.520000 10.526316
5000 9.530000 10.493179
10000 38.230000 10.462987
method 2
10 0.000000 inf
20 0.000000 inf
50 0.000000 inf
100 0.000000 inf
200 0.010000 16.000000
500 0.060000 16.666667
1000 0.260000 15.384615
2000 1.060000 15.094340
5000 6.650000 15.037594
10000 26.760000 14.947683

# %%
p1 = [20,20,20,20,16.000000,11.111111,10.810811, 10.526316, 10.493179, 10.462987]
t1 = [0,0,0,0,0.01,0.09,0.370,1.52,9.53,38.23]
p2 = [20,20,20,20,16.000000,16.666667,15.384615,15.094340, 15.037594, 14.947683]
t2 = [0,0,0,0,0.01,0.06,0.260,1.060,6.65,26.76]
print p2,t2

import matplotlib.pyplot as plt

plt.title('time consumed')
plt.plot(range(len(t1)),t1)
plt.plot(range(len(t1)),t2)

plt.show()

plt.title('performance')
plt.plot(range(len(p1)),p1)
plt.plot(range(len(p2)),p2)

plt.show()
# Out:
# [20, 20, 20, 20, 16.0, 16.666667, 15.384615, 15.09434, 15.037594, 14.947683] [0, 0, 0, 0, 0.01, 0.06, 0.26, 1.06, 6.65, 26.76]
